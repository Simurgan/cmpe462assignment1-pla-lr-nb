# %%
from pla import PLA

# %%
small_pla = PLA('PLA_data/data_small.npy', 'PLA_data/label_small.npy')
large_pla = PLA('PLA_data/data_large.npy', 'PLA_data/label_large.npy')

# %%
# Q1.1
print("----------------------------------------------------------")
small_pla.train()
print("PLA training stats for small dataset:")
small_pla.print_last_training_stats()
print("----------------------------------------------------------")
large_pla.train()
print("PLA training stats for large dataset:")
large_pla.print_last_training_stats()
print("----------------------------------------------------------")
# Out:
# ----------------------------------------------------------
# PLA training stats for small dataset:
# Number of iterations: 28
# Final weights: [-2.          3.20117277  1.64996169]
# ----------------------------------------------------------
# PLA training stats for large dataset:
# Number of iterations: 5015
# Final weights: [-37.          36.99428171  36.9864556 ]
# ----------------------------------------------------------

# %%
# Q1.2.1
small_pla.scatter_data()
small_pla.plot_decision_boundary()

# %%
# Q1.2.2
large_pla.scatter_data()
large_pla.plot_decision_boundary()

# %%
# Q1.3
import random

for i in range(5):
    print("----------------------------------------------------------")
    print(f"Training PLA with random initial weights #{i + 1}")
    initial_weights = [random.uniform(-1 * 10**(i + 1), 10**(i + 1)) for k in range(3)]
    print("Initial weights:", initial_weights)
    small_pla.train(initial_weights)
    small_pla.print_last_training_stats()
    small_pla.plot_decision_boundary()

print("----------------------------------------------------------")
# Out:
# ----------------------------------------------------------
# Training PLA with random initial weights #1
# Initial weights: [5.177849726627713, -7.420215637998804, -9.027455189710548]
# Number of iterations: 125
# Final weights: [-3.82215027  5.2888031   3.11291014]
# ----------------------------------------------------------
# Training PLA with random initial weights #2
# Initial weights: [2.821431330889638, 90.12776922018381, -82.41440681993384]
# Number of iterations: 494
# Final weights: [-33.17856867  61.02281971  18.00917422]
# ----------------------------------------------------------
# Training PLA with random initial weights #3
# Initial weights: [-791.3426122776482, -362.1731560167169, 311.25935975117636]
# Number of iterations: 1517
# Final weights: [-336.34261228  292.03009015  379.86430206]
# ----------------------------------------------------------
# Training PLA with random initial weights #4
# Initial weights: [-4085.107955062681, 8392.355107720141, -8646.111837480687]
# Number of iterations: 42400
# Final weights: [-3595.10795506  6652.31856136  1909.94501089]
# ----------------------------------------------------------
# Training PLA with random initial weights #5
# Initial weights: [-84252.54385160623, 25657.767286511007, 57828.942387961084]
# Number of iterations: 44963
# Final weights: [-57943.54385161  50159.4130257   65839.66865275]
# ----------------------------------------------------------
